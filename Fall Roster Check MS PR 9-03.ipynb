# %%
import numpy as np
import pandas as pd

# %%
rosters = pd.read_csv('xxxx.csv')
prs = pd.read_csv("xxxxxxx.csv")
term_class = pd.read_excel('xxxxxxxx.xls')
# Out:
# WARNING *** file size (1276709) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# *** No CODEPAGE record, no encoding_override: will use 'ascii'

# %%
rosters.info()
term_class.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17412 entries, 0 to 17411
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Term                            17412 non-null  int64
#  1   Course                          17412 non-null  object
#  2   Section                         17412 non-null  object
#  3   Department                      17412 non-null  object
#  4   Dept_Name                       17412 non-null  object
#  5   Subject                         17412 non-null  object
#  6   Instructor_Name                 17370 non-null  object
#  7   Campus                          17412 non-null  object
#  8   Class_School                    17412 non-null  object
#  9   Class_Name                      17412 non-null  object
#  10  Call_Number                     17412 non-null  int64
#  11  Student_Name                    17412 non-null  object
# ...

# %%
combined_rosters = pd.merge(rosters,term_class, on='Call_Number',how='inner')
#check = pd.merge(rosters,prs, on='PID',how='outer')

# %%
check = pd.merge(combined_rosters,prs, on='PID',how='inner')
check.to_excel("Incoming MS Registration 9.3.xls")

# %%
check.head()
# Out:
#    Term_x     Course Section_x Department_x  \
# 0   20203  APBME4650       001         APAM
# 1   20203  APPHE4010       001         APAM
# 2   20203  APPHE4600       001         APAM
# 3   20203  APPHE4710       001         APAM
# 4   20203  APBME4650       001         APAM
#
#                                  Dept_Name Subject_x  \
# 0  Applied Physics and Applied Mathematics      APBM
# 1  Applied Physics and Applied Mathematics      APPH
# 2  Applied Physics and Applied Mathematics      APPH
# 3  Applied Physics and Applied Mathematics      APPH
# 4  Applied Physics and Applied Mathematics      APBM
#
#               Instructor_Name_x Campus_x Class_School  \
# 0  Rozenshtein, Anna                MORN         EP
# 1       Ostrow, Stephen             MORN         EP
# 2         Meli, Jerome              MORN         EP
# 3       Ostrow, Stephen             MORN         EP
# 4  Rozenshtein, Anna                MORN         EP
#
# ...
